# %% [markdown]
# ### 1
# Системный вызов fork
#
#
# - создает точную копию родительского процесса $\large \checkmark$
#
#
# - используется для создания дочернего процесса $\large \checkmark$
#
#
# - используется для получения pid родительского процесса
#
#
# - используется для вызова функций в отдельных потоках

# %% [markdown]
# ### 2
# Системный вызов fork
#
#
# - в родительском процессе вызов fork возвращает pid дочернего $\large \checkmark$
#
#
# - в дочернем процессе вызов fork возвращает 0 $\large \checkmark$
#
#
# - в дочернем процессе вызов fork возвращает pid родительского процесса
#
#
# - в родительском процессе вызов fork возвращает 0

# %% [markdown]
# ### 3
# Что происходит с памятью в дочернем процессе при работе с Python?
#
#
# - Копируется из родительского процесса $\large \checkmark$
#
#
# - Разделяется с родительским процессом

# %% [markdown]
# ### 4
# Файловые дескрипторы в дочернем процессе
#
#
# - будут недоступны, их нужно переоткрыть заново
#
#
# - будут скопированы и переоткрыты  ?
#
#
# - будут переоткрыты Python интерпретатором автоматически  ?
#
#
# - будут скопированы ? $\large \checkmark$

# %% [markdown]
# 2, 3, 4 / 2 / 4

# %% [markdown]
# ### 5
# Выделить истинные выражения:
#
#
# - блокировки нужно брать в одном порядке, освобождать в произвольном
#
#
# - блокировки нужно брать в одном порядке, освобождать строго в том же порядке
#
#
# - блокировки нужно брать в одном порядке, освобождать в обратном $\large \checkmark$
#
#
# - предпочтительнее использовать контекстный менеджер для работы с блокировками в Python $\large \checkmark$

# %% [markdown]
# ### 6
# Очереди замедляют процесс работы потоков Python, лучше использовать объекты блокировки
#
#
# - Да
#
#
# - Нет $\large \checkmark$

# %% [markdown]
# ### 7
# Выделить истинные выражения:
#
#
# - GIL нужен для защиты памяти интерпретатора от разрушений $\large \checkmark$
#
#
# - GIL запрещает одновременное выполнение инструкций байткода в разных потоках  $\large \checkmark$
#
#
# - GIL никак не влияет на выполнение отдельных процессов на Python3 $\large \checkmark$
#
#
# - GIL замедляет выполнение главного потока управления в Python3, даже если нет других потоков

# %% [markdown]
# ###  8
# Если программа на Python выполняет много операций ввода вывода (IO-bound), то для ускорения ее работы нужно
#
#
# - разбить ее на отдельные функции, выполнить их в потоках $\large \checkmark$
#
#
# - создать отдельные процессы

# %% [markdown]
# ### 9
# Если программа на Python выполняет операции вычисления, требующие только CPU (CPU-bound), то для ускорения ее работы нужно
#
#
# - разбить ее на отдельные функции, выполнить их в потоках
#
#
# - создать отдельные процессы $\large \checkmark$

# %% [markdown]
# ### 10
# Генератор в Python – это
#
#
# - специальный вызов yield from
#
#
# - функция в которой присутствует инструкция yield $\large \checkmark$
#
#
# - объект типа concurrent.futures.Future
#
#
# - инструкция yield

# %% [markdown]
# ### 11
# Отметить все истинные утверждения:
#
#
# - исключение StopIteration используется для остановки работы итератора $\large \checkmark$
#
#
# - генератор хранит значение для генерации следующего элемента последовательности в локальных переменных $\large \checkmark$
#
#
# - итератор прерывает свое выполнение на каждой итерации, сохраняя состояние локальных переменных
#
#
# - итератор хранит значение для генерации следующего элемента последовательности в self $\large \checkmark$

# %% [markdown]
# ###  12
# Отметить все истинные утверждения:
#
#
# - сопрограммы исполняются в отдельных потоках параллельно
#
#
# - исключения нельзя обрабатывать в сопрограммах, это нужно делать в основном потоке
#
#
# - из одной сопрограммы можно вызвать другую при помощи yield from $\large \checkmark$
#
#
# - сопрограмма может прерывать свою работу, сохраняя свое состояние и значения всех локальных переменных $\large \checkmark$

# %% [markdown]
# ### 13
# Отметить все истинные утверждения, касающиеся asyncio event loop:
#
#
# - позволяет выполнять корутины, зарегистрированные в нем  $\large \checkmark$
#
#
# - выполняет несколько корутин параллельно в разных потоках
#
#
# - выполняет все корутины последовательно, переключая контекст между ними  $\large \checkmark$
#
#
# - отвечает за выделение памяти в основном процессе
#
#
# - переключает контекст между Python-потоками
#
#
# - позволяет выполнять функции и callable Python объекты

# %% [markdown]
# ### 14
# Отметить все истинные утверждения:
#
#
# - блокирующий код в Python никак не повлияет на выполнение других корутин в asyncio event loop
#
#
# - из объектов типа asyncio.Future можно создавать цепочки и дожидаться их выполнения в asyncio event loop  $\large \checkmark$
#
#
# - объект типа asyncio.Task выполняется в отдельном потоке управления, никак не влияя на выполнения других объектов типа asyncio.Task
#
#
# - объект типа asyncio.Task хранит в себе связанную корутину и содержит статус ее выполнения $\large \checkmark$
